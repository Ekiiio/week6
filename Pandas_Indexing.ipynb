# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekiiio/week6/blob/main/Pandas_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
names = ['alan','bob','charlie']
ages = [20,30,40]
city = ['NY','NY','TX']

# %%
mydata = list(zip(names,ages,city))

# %%
mydata
# Out:
# [('alan', 20, 'NY'), ('bob', 30, 'NY'), ('charlie', 40, 'TX')]

# %%
df = pd.DataFrame(data = mydata)

# %%
df
# Out:
#          0   1   2
# 0     alan  20  NY
# 1      bob  30  NY
# 2  charlie  40  TX

# %%
df = pd.DataFrame(data = mydata, columns=['names','ages','city'])

# %%
df
# Out:
#      names  ages city
# 0     alan    20   NY
# 1      bob    30   NY
# 2  charlie    40   TX

# %%
df = pd.DataFrame(data = mydata, columns=['names','ages','city'],index = ['one','two','three'])

# %%
df
# Out:
#          names  ages city
# one       alan    20   NY
# two        bob    30   NY
# three  charlie    40   TX

# %%
df.loc[['one','two'],"names"]
# Out:
# one    alan
# two     bob
# Name: names, dtype: object

# %%
df.to_csv('df.csv')

# %%
df2 = pd.read_csv('df.csv')

# %%
df2
# Out:
#   Unnamed: 0    names  ages city
# 0        one     alan    20   NY
# 1        two      bob    30   NY
# 2      three  charlie    40   TX

# %%
df.iloc[:2,1:3]
# Out:
#      ages city
# one    20   NY
# two    30   NY

# %%
df2.index = df2.iloc[:,0]

# %%
del df2[df2.columns[0]]

# %%
df2
# Out:
#               names  ages city
# Unnamed: 0
# one            alan    20   NY
# two             bob    30   NY
# three       charlie    40   TX

# %%
df2.index.name = 'hi'

# %%
df2.loc["one",'city']
# Out:
# 'NY'

# %%
df2.iloc[:,0:2]
# Out:
#          names  ages
# hi
# one       alan    20
# two        bob    30
# three  charlie    40

# %%
# Filter
df.loc[df['names']=='alan']
# Out:
#     names  ages city
# one  alan    20   NY

# %%
# Select
df.loc[:,['ages']]
# Out:
#        ages
# one      20
# two      30
# three    40

# %%
# Arrange
df.sort_values('ages',ascending=0)
# Out:
#          names  ages city
# three  charlie    40   TX
# two        bob    30   NY
# one       alan    20   NY

# %%
# Mutate 创建一个新的列FaveCity，其值为 True 或 False，具体取决于 df['city'] 列中的值是否等于 'NY'。
df['FaveCity'] = df['city'] == 'NY'

# %%
df
# Out:
#          names  ages city  FaveCity
# one       alan    20   NY      True
# two        bob    30   NY      True
# three  charlie    40   TX     False

# %%
# Groupby & Summarize
df.groupby('city')["ages"].mean()
# Out:
# city
# NY    25.0
# TX    40.0
# Name: ages, dtype: float64
